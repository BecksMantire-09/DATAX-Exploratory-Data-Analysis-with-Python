# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data_df = pd.read_csv('ecommerce_dataset_10000.csv')
data_df.head()
# Out:
#   customer_id   first_name last_name  gender  age_group signup_date  country  \
# 0    CUST2353        Erica    Oliver  Female  Teenagers   6/29/2022   Canada
# 1    CUST4463  Christopher     White    Male     Adults   8/24/2023    China
# 2    CUST4512      Spencer    Foster    Male     Senior   7/18/2023  Germany
# 3    CUST5711      Jessica    Harris    Male  Teenagers   8/22/2025   France
# 4    CUST1296          Amy   Johnson  Female  Teenagers   3/23/2021   Brazil
#
#   product_id          product_name        category  quantity  unit_price  \
# 0    PROD108        Fitbit Versa 3     Electronics         3         229
# 1    PROD103          Levi's Jeans         Apparel         4          59
# 2    PROD111    Lego Star Wars Set            Toys         2          59
# 3    PROD107          Dyson Vacuum  Home & Kitchen         4         399
# 4    PROD105  Adidas Running Shoes         Apparel         1         110
#
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     10000 non-null  object
#  1   first_name      10000 non-null  object
#  2   last_name       10000 non-null  object
#  3   gender          10000 non-null  object
#  4   age_group       10000 non-null  object
#  5   signup_date     10000 non-null  object
#  6   country         10000 non-null  object
#  7   product_id      10000 non-null  object
#  8   product_name    10000 non-null  object
#  9   category        10000 non-null  object
#  10  quantity        10000 non-null  int64
#  11  unit_price      10000 non-null  int64
#  12  order_id        10000 non-null  object
#  13  order_date      10000 non-null  object
#  14  order_status    10000 non-null  object
#  15  payment_method  10000 non-null  object
#  16  rating          10000 non-null  int64
# ...

# %%
It is observed that there are no null values in the dataset.

# %%
data_df.describe()
# Out:
#            quantity    unit_price        rating
# count  10000.000000  10000.000000  10000.000000
# mean       3.000800    246.647200      2.993100
# std        1.416474    282.605391      1.410621
# min        1.000000     25.000000      1.000000
# 25%        2.000000     80.000000      2.000000
# 50%        3.000000    129.000000      3.000000
# 75%        4.000000    229.000000      4.000000
# max        5.000000    999.000000      5.000000

# %%
it is observed that there are no outliers in the dataset.

# %%
data_df.value_counts()
# Out:
# customer_id  first_name  last_name  gender  age_group  signup_date  country  product_id  product_name          category        quantity  unit_price  order_id  order_date  order_status  payment_method    rating  review_text  review_id  review_date
# CUST5990     Gary        Mathews    Female  Adults     6/1/2025     France   PROD114     Yoga Mat              Sports          4         25          ORD14198  12/28/2023  Cancelled     Cash on Delivery  3       very bad     REV24198   3/18/2025      1
#                                                                                                                                3         25          ORD14067  1/21/2024   Shipped       PayPal            1       good         REV24067   4/2/2023       1
# ...

# %%
data_df.corr(numeric_only=True)
# Out:
#             quantity  unit_price    rating
# quantity    1.000000    0.012335 -0.001399
# unit_price  0.012335    1.000000  0.000597
# rating     -0.001399    0.000597  1.000000

# %%
it is observed that there is no correlation between the variables in the dataset.

# %%
sns.heatmap(data_df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.pairplot(data_df)

# %%
it is observed that there is no linear relationship between the variables in the dataset.

# %%
data_df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender', 'age_group',
#        'signup_date', 'country', 'product_id', 'product_name', 'category',
#        'quantity', 'unit_price', 'order_id', 'order_date', 'order_status',
#        'payment_method', 'rating', 'review_text', 'review_id', 'review_date',
#        'revenue'],
#       dtype='object')

# %%
sns.catplot(data = data_df, x = 'gender', y = 'revenue', kind = 'bar')

# %%
it is observed that there is no significant difference in the revenue between the genders.

# %%
sns.catplot(data = data_df, x = 'country', y= 'revenue', kind = 'bar')

# %%
it is observed that the revenue is highest in the Japan.

# %%
sns.catplot(data = data_df, x = 'age_group', kind = 'count')

# %%
data_df['revenue'] = data_df['quantity'] * data_df['unit_price']
sns.relplot(data = data_df, x = 'unit_price', y = 'category', kind= 'scatter')

# %%
it is observed that the revenue is highest in the category of Electronics.

# %%
sns.catplot(data = data_df, x = 'age_group', y = 'revenue', kind= 'box')
